# %%
import statsmodels.api as sm
import sklearn
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
import numpy as np
import pandas as pd
from pandas import DataFrame

# %%
#Quarterly MSE Calculation

np.random.seed(42)
num_folds = 10
dependent = range(11,18)

#CIBC

r2_list=[]
mse_list=[]
for num in dependent:
    dataframe = pd.read_csv("CIBC.csv")
    X = dataframe.iloc[:,5:11]
    Y = dataframe.iloc[:,num]
    X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size = 0.20)

    lm = linear_model.LinearRegression()
    model = lm.fit(X_train,y_train)
    row1=[]
    row2=[]
    for i in range(32):
        dataframe = pd.read_csv("CIBC.csv")
        dataframe = dataframe[dataframe['Quarter']==i+1]
        X = dataframe.iloc[:,5:11]
        Y = dataframe.iloc[:,num]
        X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size = 0.20)
        
        r2 = lm.score(X_test,y_test)
        y_pred = model.predict(X_test)
        mse=mean_squared_error(y_test,y_pred)
        row1.append(r2)
        row2.append(mse)
    r2_list.append(row1)
    #print(r2_list)
    mse_list.append(row2)
cibc_linear_mse = DataFrame(mse_list).transpose()
cibc_linear_mse.columns = ['ROA','ROS','Operating Income to Sales','Opearting Income to Assets','Operating Expenses to Sales','Cost of Goods to Sales','Selling, General and Administrative Expenses to Sales']
cibc_linear_mse['Bank']="CIBC"

#BMO

r2_list=[]
mse_list=[]
for num in dependent:
    dataframe = pd.read_csv("BMO.csv")
    X = dataframe.iloc[:,5:11]
    Y = dataframe.iloc[:,num]
    X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size = 0.20)

    lm = linear_model.LinearRegression()
    model = lm.fit(X_train,y_train)
    row1=[]
    row2=[]
    for i in range(32):
        dataframe = pd.read_csv("BMO.csv")
        dataframe = dataframe[dataframe['Quarter']==i+1]
        X = dataframe.iloc[:,5:11]
        Y = dataframe.iloc[:,num]
        X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size = 0.20)
        
        r2 = lm.score(X_test,y_test)
        y_pred = model.predict(X_test)
        mse=mean_squared_error(y_test,y_pred)
        row1.append(r2)
        row2.append(mse)
    r2_list.append(row1)
    #print(r2_list)
    mse_list.append(row2)
bmo_linear_mse = DataFrame(mse_list).transpose()
bmo_linear_mse.columns = ['ROA','ROS','Operating Income to Sales','Opearting Income to Assets','Operating Expenses to Sales','Cost of Goods to Sales','Selling, General and Administrative Expenses to Sales']
bmo_linear_mse['Bank']="BMO"

#TD

r2_list=[]
mse_list=[]
for num in dependent:
    dataframe = pd.read_csv("TD.csv")
    X = dataframe.iloc[:,5:11]
    Y = dataframe.iloc[:,num]
    X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size = 0.20)

    lm = linear_model.LinearRegression()
    model = lm.fit(X_train,y_train)
    row1=[]
    row2=[]
    for i in range(32):
        dataframe = pd.read_csv("TD.csv")
        dataframe = dataframe[dataframe['Quarter']==i+1]
        X = dataframe.iloc[:,5:11]
        Y = dataframe.iloc[:,num]
        X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size = 0.20)
        
        r2 = lm.score(X_test,y_test)
        y_pred = model.predict(X_test)
        mse=mean_squared_error(y_test,y_pred)
        row1.append(r2)
        row2.append(mse)
    r2_list.append(row1)
    #print(r2_list)
    mse_list.append(row2)
td_linear_mse = DataFrame(mse_list).transpose()
td_linear_mse.columns = ['ROA','ROS','Operating Income to Sales','Opearting Income to Assets','Operating Expenses to Sales','Cost of Goods to Sales','Selling, General and Administrative Expenses to Sales']
td_linear_mse['Bank']="TD"

#RBC

r2_list=[]
mse_list=[]
for num in dependent:
    dataframe = pd.read_csv("RBC.csv")
    X = dataframe.iloc[:,5:11]
    Y = dataframe.iloc[:,num]
    X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size = 0.20)

    lm = linear_model.LinearRegression()
    model = lm.fit(X_train,y_train)
    row1=[]
    row2=[]
    for i in range(32):
        dataframe = pd.read_csv("RBC.csv")
        dataframe = dataframe[dataframe['Quarter']==i+1]
        X = dataframe.iloc[:,5:11]
        Y = dataframe.iloc[:,num]
        X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size = 0.20)
        
        r2 = lm.score(X_test,y_test)
        y_pred = model.predict(X_test)
        mse=mean_squared_error(y_test,y_pred)
        row1.append(r2)
        row2.append(mse)
    r2_list.append(row1)
    #print(r2_list)
    mse_list.append(row2)
rbc_linear_mse = DataFrame(mse_list).transpose()
rbc_linear_mse.columns = ['ROA','ROS','Operating Income to Sales','Opearting Income to Assets','Operating Expenses to Sales','Cost of Goods to Sales','Selling, General and Administrative Expenses to Sales']
rbc_linear_mse['Bank']="RBC"

#Scotia

r2_list=[]
mse_list=[]
for num in dependent:
    dataframe = pd.read_csv("Scotia.csv")
    X = dataframe.iloc[:,5:11]
    Y = dataframe.iloc[:,num]
    X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size = 0.20)

    lm = linear_model.LinearRegression()
    model = lm.fit(X_train,y_train)
    row1=[]
    row2=[]
    for i in range(32):
        dataframe = pd.read_csv("Scotia.csv")
        dataframe = dataframe[dataframe['Quarter']==i+1]
        X = dataframe.iloc[:,5:11]
        Y = dataframe.iloc[:,num]
        X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size = 0.20)
        
        r2 = lm.score(X_test,y_test)
        y_pred = model.predict(X_test)
        mse=mean_squared_error(y_test,y_pred)
        row1.append(r2)
        row2.append(mse)
    r2_list.append(row1)
    #print(r2_list)
    mse_list.append(row2)
scotia_linear_mse = DataFrame(mse_list).transpose()
scotia_linear_mse.columns = ['ROA','ROS','Operating Income to Sales','Opearting Income to Assets','Operating Expenses to Sales','Cost of Goods to Sales','Selling, General and Administrative Expenses to Sales']
scotia_linear_mse['Bank']="Scotia"

# %%
#Baseline MSE and r2 for entire dataset

np.random.seed(42)
num_folds = 5
dependent = range(11,18)

#BMO

r2_dependent=[]
mse_dependent=[]

for num in dependent:
    dataframe = pd.read_csv("BMO.csv")
    X = dataframe.iloc[:,5:11]
    Y = dataframe.iloc[:,num]
    kfold = KFold(n_splits=num_folds, shuffle=True)
    r2_list=[]
    mse_list=[]
    for train, test in kfold.split(X, Y):
        lm = linear_model.LinearRegression()
        model = lm.fit(X.iloc[train],Y.iloc[train])
        r2 = model.score(X.iloc[test],Y.iloc[test])
        y_pred = model.predict(X.iloc[test])
        mse=mean_squared_error(Y.iloc[test],y_pred)
        r2_list.append(r2)
        mse_list.append(mse)
    r2_dependent.append(np.mean(r2_list))
    mse_dependent.append(np.mean(mse_list))
bmo_linear_r2 = DataFrame(r2_dependent).transpose()
bmo_linear_r2.columns = ['ROA','ROS','Operating Income to Sales','Opearting Income to Assets','Operating Expenses to Sales','Cost of Goods to Sales','Selling, General and Administrative Expenses to Sales']
bmo_linear_r2['Bank']="BMO"
bmo_linear_mse = DataFrame(mse_dependent).transpose()
bmo_linear_mse.columns = ['ROA','ROS','Operating Income to Sales','Opearting Income to Assets','Operating Expenses to Sales','Cost of Goods to Sales','Selling, General and Administrative Expenses to Sales']
bmo_linear_mse['Bank']="BMO"

#CIBC

r2_dependent=[]
mse_dependent=[]

for num in dependent:
    dataframe = pd.read_csv("CIBC.csv")
    X = dataframe.iloc[:,5:11]
    Y = dataframe.iloc[:,num]
    kfold = KFold(n_splits=num_folds, shuffle=True)
    r2_list=[]
    mse_list=[]
    for train, test in kfold.split(X, Y):
        lm = linear_model.LinearRegression()
        model = lm.fit(X.iloc[train],Y.iloc[train])
        r2 = model.score(X.iloc[test],Y.iloc[test])
        y_pred = model.predict(X.iloc[test])
        mse=mean_squared_error(Y.iloc[test],y_pred)
        r2_list.append(r2)
        mse_list.append(mse)
    r2_dependent.append(np.mean(r2_list))
    mse_dependent.append(np.mean(mse_list))
cibc_linear_r2 = DataFrame(r2_dependent).transpose()
cibc_linear_r2.columns = ['ROA','ROS','Operating Income to Sales','Opearting Income to Assets','Operating Expenses to Sales','Cost of Goods to Sales','Selling, General and Administrative Expenses to Sales']
cibc_linear_r2['Bank']="CIBC"
cibc_linear_mse = DataFrame(mse_dependent).transpose()
cibc_linear_mse.columns = ['ROA','ROS','Operating Income to Sales','Opearting Income to Assets','Operating Expenses to Sales','Cost of Goods to Sales','Selling, General and Administrative Expenses to Sales']
cibc_linear_mse['Bank']="CIBC"

#TD

r2_dependent=[]
mse_dependent=[]

for num in dependent:
    dataframe = pd.read_csv("TD.csv")
    X = dataframe.iloc[:,5:11]
    Y = dataframe.iloc[:,num]
    kfold = KFold(n_splits=num_folds, shuffle=True)
    r2_list=[]
    mse_list=[]
    for train, test in kfold.split(X, Y):
        lm = linear_model.LinearRegression()
        model = lm.fit(X.iloc[train],Y.iloc[train])
        r2 = model.score(X.iloc[test],Y.iloc[test])
        y_pred = model.predict(X.iloc[test])
        mse=mean_squared_error(Y.iloc[test],y_pred)
        r2_list.append(r2)
        mse_list.append(mse)
    r2_dependent.append(np.mean(r2_list))
    mse_dependent.append(np.mean(mse_list))
td_linear_r2 = DataFrame(r2_dependent).transpose()
td_linear_r2.columns = ['ROA','ROS','Operating Income to Sales','Opearting Income to Assets','Operating Expenses to Sales','Cost of Goods to Sales','Selling, General and Administrative Expenses to Sales']
td_linear_r2['Bank']="TD"
td_linear_mse = DataFrame(mse_dependent).transpose()
td_linear_mse.columns = ['ROA','ROS','Operating Income to Sales','Opearting Income to Assets','Operating Expenses to Sales','Cost of Goods to Sales','Selling, General and Administrative Expenses to Sales']
td_linear_mse['Bank']="TD"

#RBC

r2_dependent=[]
mse_dependent=[]

for num in dependent:
    dataframe = pd.read_csv("RBC.csv")
    X = dataframe.iloc[:,5:11]
    Y = dataframe.iloc[:,num]
    kfold = KFold(n_splits=num_folds, shuffle=True)
    r2_list=[]
    mse_list=[]
    for train, test in kfold.split(X, Y):
        lm = linear_model.LinearRegression()
        model = lm.fit(X.iloc[train],Y.iloc[train])
        r2 = model.score(X.iloc[test],Y.iloc[test])
        y_pred = model.predict(X.iloc[test])
        mse=mean_squared_error(Y.iloc[test],y_pred)
        r2_list.append(r2)
        mse_list.append(mse)
    r2_dependent.append(np.mean(r2_list))
    mse_dependent.append(np.mean(mse_list))
rbc_linear_r2 = DataFrame(r2_dependent).transpose()
rbc_linear_r2.columns = ['ROA','ROS','Operating Income to Sales','Opearting Income to Assets','Operating Expenses to Sales','Cost of Goods to Sales','Selling, General and Administrative Expenses to Sales']
rbc_linear_r2['Bank']="RBC"
rbc_linear_mse = DataFrame(mse_dependent).transpose()
rbc_linear_mse.columns = ['ROA','ROS','Operating Income to Sales','Opearting Income to Assets','Operating Expenses to Sales','Cost of Goods to Sales','Selling, General and Administrative Expenses to Sales']
rbc_linear_mse['Bank']="RBC"

#Scotia

r2_dependent=[]
mse_dependent=[]

for num in dependent:
    dataframe = pd.read_csv("scotia.csv")
    X = dataframe.iloc[:,5:11]
    Y = dataframe.iloc[:,num]
    kfold = KFold(n_splits=num_folds, shuffle=True)
    r2_list=[]
    mse_list=[]
    for train, test in kfold.split(X, Y):
        lm = linear_model.LinearRegression()
        model = lm.fit(X.iloc[train],Y.iloc[train])
        r2 = model.score(X.iloc[test],Y.iloc[test])
        y_pred = model.predict(X.iloc[test])
        mse=mean_squared_error(Y.iloc[test],y_pred)
        r2_list.append(r2)
        mse_list.append(mse)
    r2_dependent.append(np.mean(r2_list))
    mse_dependent.append(np.mean(mse_list))
scotia_linear_r2 = DataFrame(r2_dependent).transpose()
scotia_linear_r2.columns = ['ROA','ROS','Operating Income to Sales','Opearting Income to Assets','Operating Expenses to Sales','Cost of Goods to Sales','Selling, General and Administrative Expenses to Sales']
scotia_linear_r2['Bank']="Scotia"
scotia_linear_mse = DataFrame(mse_dependent).transpose()
scotia_linear_mse.columns = ['ROA','ROS','Operating Income to Sales','Opearting Income to Assets','Operating Expenses to Sales','Cost of Goods to Sales','Selling, General and Administrative Expenses to Sales']
scotia_linear_mse['Bank']="Scotia"

# %%
#Concatenate Dataframes

cibc_linear_r2
cibc_linear_mse
bmo_linear_r2
bmo_linear_mse
rbc_linear_r2
rbc_linear_mse
td_linear_r2
td_linear_mse
scotia_linear_r2
scotia_linear_mse
Baseline_linear_mse = pd.concat([cibc_linear_mse,bmo_linear_mse,rbc_linear_mse,td_linear_mse,scotia_linear_mse])
Baseline_linear_r2 = pd.concat([cibc_linear_r2,bmo_linear_r2,rbc_linear_r2,td_linear_r2,scotia_linear_r2])
